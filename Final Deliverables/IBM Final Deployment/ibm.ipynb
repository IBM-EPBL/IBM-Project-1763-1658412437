# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.models import Model
from tensorflow.keras.layers import LSTM, Activation, Dense, Dropout, Input, Embedding
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping
# %matplotlib inline

# %%
import abc
import functools
import multiprocessing
import sys
import threading
import warnings

import numpy as np
import six

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing.image import ImageDataGenerator
train_datagen=ImageDataGenerator(rescale = 1./255, shear_range=0.2, zoom_range=0.2, horizontal_flip=True) 
test_datagen=ImageDataGenerator(rescale = 1./255)

# %%
import os, types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.
cos_client = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='9vdSI7g2z2jLUUVDiGhYOWA__qZoE2qN4ATZyQ0aESQV',
    ibm_auth_endpoint="https://iam.cloud.ibm.com/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3.private.us.cloud-object-storage.appdomain.cloud')

bucket = 'image-donotdelete-pr-h8rsrpiyjmy2lx'
object_key = 'testset.zip'

streaming_body_4 = cos_client.get_object(Bucket=bucket, Key=object_key)['Body']

# Your data file was loaded into a botocore.response.StreamingBody object.
# Please read the documentation of ibm_boto3 and pandas to learn more about the possibilities to load the data.
# ibm_boto3 documentation: https://ibm.github.io/ibm-cos-sdk-python/
# pandas documentation: http://pandas.pydata.org/

# %%
from io import BytesIO
import zipfile 
unzip=zipfile.ZipFile(BytesIO(streaming_body_4.read())) 
file_paths = unzip.namelist() 
for path in file_paths: 
    unzip.extract(path)

# %%
pwd
# Out:
# '/home/wsuser/work'

# %%
import os, types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.
cos_client = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='9vdSI7g2z2jLUUVDiGhYOWA__qZoE2qN4ATZyQ0aESQV',
    ibm_auth_endpoint="https://iam.cloud.ibm.com/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3.private.us.cloud-object-storage.appdomain.cloud')

bucket = 'image-donotdelete-pr-h8rsrpiyjmy2lx'
object_key = 'trainset.zip'

streaming_body_5 = cos_client.get_object(Bucket=bucket, Key=object_key)['Body']

# Your data file was loaded into a botocore.response.StreamingBody object.
# Please read the documentation of ibm_boto3 and pandas to learn more about the possibilities to load the data.
# ibm_boto3 documentation: https://ibm.github.io/ibm-cos-sdk-python/
# pandas documentation: http://pandas.pydata.org/

# %%
from io import BytesIO
import zipfile 
unzip=zipfile.ZipFile(BytesIO(streaming_body_5.read())) 
file_paths = unzip.namelist() 
for path in file_paths: 
    unzip.extract(path)

# %%
pwd
# Out:
# '/home/wsuser/work'

# %%
dir='/home/wsuser/work/trainset'

# %%
dir1='/home/wsuser/work/testset'

# %%
train_datagen = ImageDataGenerator(rescale=1./255,
                                   zoom_range=0.2,
                                   horizontal_flip=True)

# %%
test_datagen = ImageDataGenerator(rescale=1./255)

# %%
xtrain = train_datagen.flow_from_directory(dir,target_size=(64,64),class_mode='categorical',batch_size=100)
# Out:
# Found 15750 images belonging to 9 classes.

# %%
xtest = test_datagen.flow_from_directory(dir1,
                                         target_size=(64,64),
                                         class_mode='categorical',
                                         batch_size=100)
# Out:
# Found 2250 images belonging to 9 classes.

# %%
xtrain.class_indices
# Out:
# {'A': 0, 'B': 1, 'C': 2, 'D': 3, 'E': 4, 'F': 5, 'G': 6, 'H': 7, 'I': 8}

# %%
xtest.class_indices
# Out:
# {'A': 0, 'B': 1, 'C': 2, 'D': 3, 'E': 4, 'F': 5, 'G': 6, 'H': 7, 'I': 8}

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Convolution2D
from keras.layers import MaxPooling2D
from keras.layers import Dropout
from keras.layers import Flatten

# %%
model=Sequential()

# %% [markdown]
# # Convolution Layer

# %%
model.add(Convolution2D(32,(3,3),activation='relu',input_shape=(64,64,3)))

# %% [markdown]
# #Maxpooling Layer

# %%
model.add(MaxPooling2D(pool_size=(2,2)))

# %% [markdown]
# #Flatten Layer

# %%
model.add(Flatten())

# %% [markdown]
# #Dense Layers

# %%
model.add(Dense (units=512, activation='relu')) 
model.add(Dense (units=9, activation='softmax'))

# %% [markdown]
# #Compile The Model

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# #train

# %%
from keras.callbacks import EarlyStopping, ReduceLROnPlateau

# %%
early_stopping = EarlyStopping(monitor='val_accuracy',
                        patience=5)
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy',
                        patience=5,
                        factor=0.5,min_lr=0.00001)

callback = [reduce_lr,early_stopping]

# %%
model.fit(xtrain,
            steps_per_epoch=len(xtrain),
            epochs=10,
            callbacks=callback,
            validation_data=xtest,
            validation_steps=len(xtest))
# Out:
# Epoch 1/10
# 158/158 [==============================] - 92s 576ms/step - loss: 0.5574 - accuracy: 0.8719 - val_loss: 0.2397 - val_accuracy: 0.9671 - lr: 0.0010
# Epoch 2/10
# 158/158 [==============================] - 91s 575ms/step - loss: 0.0427 - accuracy: 0.9897 - val_loss: 0.2304 - val_accuracy: 0.9773 - lr: 0.0010
# Epoch 3/10
# 158/158 [==============================] - 93s 585ms/step - loss: 0.0168 - accuracy: 0.9964 - val_loss: 0.2980 - val_accuracy: 0.9760 - lr: 0.0010
# Epoch 4/10
# 158/158 [==============================] - 90s 567ms/step - loss: 0.0062 - accuracy: 0.9985 - val_loss: 0.3321 - val_accuracy: 0.9756 - lr: 0.0010
# Epoch 5/10
# 158/158 [==============================] - 89s 563ms/step - loss: 0.0086 - accuracy: 0.9973 - val_loss: 0.3857 - val_accuracy: 0.9764 - lr: 0.0010
# Epoch 6/10
# 158/158 [==============================] - 91s 576ms/step - loss: 0.0057 - accuracy: 0.9987 - val_loss: 0.3817 - val_accuracy: 0.9760 - lr: 0.0010
# Epoch 7/10
# ...

# %%
model.save('Sign.h5')

# %%
from skimage.transform import resize 
def detect(frame):
  img=resize(frame, (64,64,1))
  img= np.expand_dims (img,axis=0)
  if(np.max(img)>1):
    img=img/255.0
    prediction = model.predict(img)
    print(prediction)
    prediction = model.predict_classes(img) 
    print(prediction)

# %%
# !tar -zcvf image_new.tgz Sign.h5

# %%
ls -1

# %%
# !pip install watson-machine-learning-client --upgrade

# %%
from ibm_watson_machine_learning import APIClient
wml_credentials = {
                "url": "https://us-south.ml.cloud.ibm.com", 
                "apikey":"tAYbVVZ3PddPDKW8i7-xBErcgmKJ6wgK9-XtP7ZdPY0q"
}
client=APIClient(wml_credentials)

# %%
client=APIClient(wml_credentials)

# %%
def guid_from_space_name(client, space_name):
    space=client.spaces.get_details()  
    return(next(item for item in space['resources'] if item['entity']["name"]== space_name)['metadata']['id'])

# %%
space_uid=guid_from_space_name(client,'imagesign')
print("Space UID=" + space_uid)

# %%
client.set.default_space(space_uid)

# %%
client.software_specifications.list()

# %%
software_spec_uid= client.software_specifications.get_uid_by_name("tensorflow_rt22.1-py3.9") 
software_spec_uid

# %%
model_details=client.repository.store_model(model='image_new.tgz',meta_props={
client.repository.ModelMetaNames.NAME: "CNN",
client.repository.ModelMetaNames. TYPE: "tensorflow_2.7",
client.repository.ModelMetaNames.SOFTWARE_SPEC_UID: software_spec_uid}
                                           )
model_id=client.repository.get_model_uid(model_details)

# %%
model_id

# %%
client.repository.download (model_id, 'my_model.tar.gz')

# %%
from keras.models import load_model 
from keras.preprocessing import image

# %%
model=load_model("Sign.h5")

# %%
import os, types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.
cos_client = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='9vdSI7g2z2jLUUVDiGhYOWA__qZoE2qN4ATZyQ0aESQV',
    ibm_auth_endpoint="https://iam.cloud.ibm.com/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3.private.us.cloud-object-storage.appdomain.cloud')

bucket = 'image-donotdelete-pr-h8rsrpiyjmy2lx'
object_key = 'a.jpg'

streaming_body_9 = cos_client.get_object(Bucket=bucket, Key=object_key)['Body']

# Your data file was loaded into a botocore.response.StreamingBody object.
# Please read the documentation of ibm_boto3 and pandas to learn more about the possibilities to load the data.
# ibm_boto3 documentation: https://ibm.github.io/ibm-cos-sdk-python/
# pandas documentation: http://pandas.pydata.org/
img = image.load_img(streaming_body_9,target_size = (64,64))

# %%
ls -l
