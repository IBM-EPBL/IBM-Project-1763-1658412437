# %% [markdown]
# #MODEL BUILDING

# %%
from keras.preprocessing.image import ImageDataGenerator
train_datagen=ImageDataGenerator(rescale = 1./255, shear_range=0.2, zoom_range=0.2,horizontal_flip=True)
test_datagen = ImageDataGenerator(rescale=1./255)

# %%
# !unzip '/content/sample_data/Dataset/trainset.zip'
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: trainset/G/1225.png
#   inflating: trainset/G/1226.png
#   inflating: trainset/G/1227.png
#   inflating: trainset/G/1228.png
#   inflating: trainset/G/1229.png
#   inflating: trainset/G/123.png
#   inflating: trainset/G/1230.png
#   inflating: trainset/G/1231.png
#   inflating: trainset/G/1232.png
#   inflating: trainset/G/1233.png
#   inflating: trainset/G/1234.png
#   inflating: trainset/G/1235.png
#   inflating: trainset/G/1236.png
#   inflating: trainset/G/1237.png
#   inflating: trainset/G/1238.png
#   inflating: trainset/G/1239.png
#   inflating: trainset/G/124.png
#   inflating: trainset/G/1240.png
#   inflating: trainset/G/1241.png
#   inflating: trainset/G/1242.png
#   inflating: trainset/G/1243.png
#   inflating: trainset/G/1244.png
#   inflating: trainset/G/1245.png
#   inflating: trainset/G/1246.png
#   inflating: trainset/G/1247.png
#   inflating: trainset/G/1248.png
#   inflating: trainset/G/1249.png
# ...

# %%
x_train = train_datagen.flow_from_directory("/content/trainset", target_size=(64,64),batch_size=300,
                                            class_mode='categorical', color_mode ="grayscale")
# Out:
# Found 15750 images belonging to 9 classes.

# %%
# !unzip '/content/sample_data/Dataset/testset.zip'
# Out:
# Archive:  /content/sample_data/Dataset/testset.zip
#    creating: testset/
#    creating: testset/A/
#   inflating: testset/A/1.png
#   inflating: testset/A/10.png
#   inflating: testset/A/100.png
#   inflating: testset/A/101.png
#   inflating: testset/A/102.png
#   inflating: testset/A/103.png
#   inflating: testset/A/104.png
#   inflating: testset/A/105.png
#   inflating: testset/A/106.png
#   inflating: testset/A/107.png
#   inflating: testset/A/108.png
#   inflating: testset/A/109.png
#   inflating: testset/A/11.png
#   inflating: testset/A/110.png
#   inflating: testset/A/111.png
#   inflating: testset/A/112.png
#   inflating: testset/A/113.png
#   inflating: testset/A/114.png
#   inflating: testset/A/115.png
#   inflating: testset/A/116.png
#   inflating: testset/A/117.png
#   inflating: testset/A/118.png
#   inflating: testset/A/119.png
#   inflating: testset/A/12.png
#   inflating: testset/A/120.png
#   inflating: testset/A/121.png
#   inflating: testset/A/122.png
# ...

# %%
x_test = test_datagen.flow_from_directory("/content/testset", target_size=(64,64),batch_size=300,
                                         class_mode='categorical', color_mode ="grayscale")
# Out:
# Found 2250 images belonging to 9 classes.

# %% [markdown]
# #MODEL BUILDING

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Convolution2D
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from keras.layers import Dropout
from keras.layers import Flatten

# %%
model=Sequential()

# %%
model.add(Convolution2D(32,(3,3), input_shape=(64,64,1), activation = 'relu'))

# %%
model.add(MaxPooling2D(pool_size=(2,2)))

# %%
model.add(Flatten())

# %%
model.add(Dense( units=512, activation='relu'))

# %%
model.add(Dense(units=9, activation='softmax'))

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.fit_generator(x_train, steps_per_epoch=24, epochs=10, validation_data=x_test,validation_steps=40)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   """Entry point for launching an IPython kernel.
# Epoch 1/10
# 24/24 [==============================] - ETA: 0s - loss: 0.8931 - accuracy: 0.7146
# WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 40 batches). You may need to use the repeat() function when building your dataset.
# 24/24 [==============================] - 40s 2s/step - loss: 0.8931 - accuracy: 0.7146 - val_loss: 0.3542 - val_accuracy: 0.9102
# Epoch 2/10
# 24/24 [==============================] - 33s 1s/step - loss: 0.2005 - accuracy: 0.9421
# Epoch 3/10
# 24/24 [==============================] - 33s 1s/step - loss: 0.1078 - accuracy: 0.9722
# Epoch 4/10
# ...

# %%
model.save('Sign.h5')
